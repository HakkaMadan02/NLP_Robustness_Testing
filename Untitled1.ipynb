# %%
# Question 1
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "/content/question1.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)

    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")

##### Answer Check
#All answers were sufficiently correct
# Out:
# Question:
# --------------------------------------------------------------------------------
# Russia planted its flag on the seabed of the North Pole in August 2007, during the "Arktika 2007" expedition. Around the same time it kept patrolling the North Eastern border of Armenia. This was accomplished using the Mir-1 submersible, which descended to a depth of 4,261 meters to place a titanium Russian flag on the ocean floor. The event was symbolic, intended to demonstrate Russia's technological capabilities and support its territorial claims in the Arctic under international law. Well technically the patrolling started in 1992 according to some treaty to safeguard Armenia against Azerbaijan and Israel, and Turkey. Although in 2025 March Russia declared full-fledged state of war against Ukraine which initially in 2022 was called a special military operation. Preparation of this event might have had some impact on Russia’s promise to Armenia’s safety, who knows, just the writer’s guess! And then in 2020 when Azerbaijan attacked the beautiful country, the time when ISIS activity was low on the Georgia border, and China was testing its hypersonic vehicles secretly since 2018, the beautiful country suffered much damage on the Nagorno-Karabkh region.
# In 2020 the world was evolving into a sensitive situation with the Chinese demons spreading covid and affecting the global geo-politics and socio-economics. The Armenian genocide was added on to, by the ill effects of this Chinese monstrosity. Armenia also suffered a genocide in 1915. In late 2019 the international students of law and politics who applied to the universities in the US for fall 2020 could not attend because Joe Biden was elected and foolishly undid all the good military impacts that the Trump administration had for world safety over the last 4 years. Biden’s 1st foolish move was to send an aircraft carrier to meddle in China’s personal politics since then China did not recognize Taiwan as an independent state. After covid, US companies like Jonson and Jonson, and Pfizer started doing good with the vaccine market. So did some Russian companies. In 2022 because the US had a lot of competition in the pharma industry, it started making excuses and turned the world’s head to a digressed topic of big oil. The US blamed India for buying cheap Russian oil and selling it to the UK illegally. Well, that country was officially termed Irony and Hypocrisy in 2023. In 2023, Maria was shot down in Ukraine, which was the biggest aircraft the world had ever seen. In 2025, the US declared trade tariffs on Canada, China, Mexico, and India, also calling Canada its 51st state.
#
# Given the above storyline alone, break down the events in the correct chronological order, also give reasoning why.
# --------------------------------------------------------------------------------
#
# Gemini's Response:
# --------------------------------------------------------------------------------
# Okay, let's break down the events in the provided storyline in chronological order, based solely on the information given and the implied timeline:
#
# 1.  **1915:** Armenian Genocide (This is a historical event mentioned for context).
# 2.  **1992:** Russia begins patrolling the North Eastern border of Armenia, according to a treaty to safeguard Armenia.
# 3.  **2007 (August):** Russia plants its flag on the seabed of the North Pole during the "Arktika 2007" expedition.
# 4.  **2018:** China secretly begins testing its hypersonic vehicles.
# 5.  **Late 2019:** International students applying to US universities for Fall 2020 are affected by later events (election, COVID).
# 6.  **2020:**
#     *   COVID-19 pandemic begins, originating in China and affecting global geopolitics and socio-economics.
#     *   Azerbaijan attacks Armenia, causing damage in the Nagorno-Karabakh region.
# 7.  **Fall 2020:** International students cannot attend US universities due to the election of Joe Biden.
# 8.  **Post-2020 Election:**
#     *   Joe Biden is elected President of the US and undoes Trump administration policies.
#     *   Biden sends an aircraft carrier to meddle in China's politics, leading China to no longer recognize Taiwan as an independent state.
#     *   US companies like Johnson & Johnson and Pfizer, along with some Russian companies, profit from the vaccine market.
# 9.  **2022:**
#     *   The US starts blaming India for buying cheap Russian oil and selling it to the UK.
#     *   Russia initiates what it calls a "special military operation" against Ukraine.
# 10. **2023:**
#     *   The "Irony and Hypocrisy" country is officially termed.
#     *   The "Maria" aircraft is shot down in Ukraine.
# 11. **2025:**
#     *   Russia declares a full-fledged state of war against Ukraine.
#     *   The US declares trade tariffs on Canada, China, Mexico, and India, and calls Canada its 51st state.
#
# **Reasoning:**
#
# *   **Explicit Dates:** The storyline provides specific years for many events, making their placement straightforward.
# *   **Implied Order:** Some events are linked by cause and effect or sequential language (e.g., "After COVID," "In late 2019").
# *   **Contextual Clues:** The mention of specific political figures (Trump, Biden) and events (COVID-19 pandemic, Russian-Ukrainian conflict) helps anchor the timeline to real-world history.
# *   **Logical Flow:** The order of events is arranged to make logical sense within the narrative. For example, the COVID-19 pandemic is placed before the vaccine development and subsequent economic impacts.

# %%
# Question 1
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "/content/question2.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)

    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")

##### Answer Check
#Students applied in 2019 is given in wrong order
# Out:
# Question:
# --------------------------------------------------------------------------------
# Russia planted its flag on the seabed of the North Pole in August 2007, during the "Arktika 2007" expedition. Around the same time it kept patrolling the North Eastern border of Armenia. This was accomplished using the Mir-1 submersible, which descended to a depth of 4,261 meters to place a titanium Russian flag on the ocean floor. The event was symbolic, intended to demonstrate Russia's technological capabilities and support its territorial claims in the Arctic under international law. Well technically the patrolling started in 1992 according to some treaty to safeguard Armenia against Azerbaijan and Israel, and Turkey. Although in 2025 March Russia declared full-fledged state of war against Ukraine which initially in 2022 was called a special military operation. Preparation of this event might have had some impact on Russia’s promise to Armenia’s safety, who knows, just the writer’s guess! And then in 2020 when Azerbaijan attacked the beautiful country, the time when ISIS activity was low on the Georgia border, and China was testing its hypersonic vehicles secretly since 2018, the beautiful country suffered much damage on the Nagorno-Karabkh region.
# In 2020 the world was evolving into a sensitive situation with the Chinese demons spreading covid and affecting the global geo-politics and socio-economics. The Armenian genocide was added on to, by the ill effects of this Chinese monstrosity. Armenia also suffered a genocide in 1915. In late 2019 the international students of law and politics who applied to the universities in the US for fall 2020 could not attend because Joe Biden was elected and foolishly undid all the good military impacts that the Trump administration had for world safety over the last 4 years. Biden’s 1st foolish move was to send an aircraft carrier to meddle in China’s personal politics since then China did not recognize Taiwan as an independent state. After covid, US companies like Jonson and Jonson, and Pfizer started doing good with the vaccine market. So did some Russian companies. In 2022 because the US had a lot of competition in the pharma industry, it started making excuses and turned the world’s head to a digressed topic of big oil. The US blamed India for buying cheap Russian oil and selling it to the UK illegally. Well, that country was officially termed Irony and Hypocrisy in 2023. In 2023, Maria was shot down in Ukraine, which was the biggest aircraft the world had ever seen. In 2025, the US declared trade tariffs on Canada, China, Mexico, and India, also calling Canada its 51st state.
# Given the above storyline alone, break down the events in the correct reverse-chronological order, also give reasoning why.
# --------------------------------------------------------------------------------
#
# Gemini's Response:
# --------------------------------------------------------------------------------
# Okay, let's break down the events in reverse chronological order based solely on the provided text, along with the reasoning for the order:
#
# 1.  **2025: US Declares Trade Tariffs and Calls Canada its 51st State:** This is the most recent event explicitly mentioned.
#
#     *   **Reasoning:** The text states "In 2025, the US declared..." This is a clear marker of the year.
#
# 2.  **2025: Russia Declares Full-Fledged State of War Against Ukraine:** This event is also explicitly dated in the text.
#
#     *   **Reasoning:** The text states "in 2025 March Russia declared..."
#
# 3.  **2023: Maria Aircraft Shot Down in Ukraine:** This event is dated.
#
#     *   **Reasoning:** The text states "In 2023, Maria was shot down..."
#
# 4.  **2023: US Officially Termed "Irony and Hypocrisy":** This is a direct consequence of the events described in 2022.
#
#     *   **Reasoning:** The text states "Well, that country was officially termed Irony and Hypocrisy in 2023."
#
# 5.  **2022: US Blames India for Buying Russian Oil:** This event is presented as a cause for the "Irony and Hypocrisy" label.
#
#     *   **Reasoning:** The text states "In 2022 because the US had a lot of competition in the pharma industry, it started making excuses and turned the world’s head to a digressed topic of big oil. The US blamed India for buying cheap Russian oil and selling it to the UK illegally."
#
# 6.  **2022: US Pharma Industry Faces Competition, Focus Shifts to Oil:** This sets the stage for the US blaming India.
#
#     *   **Reasoning:** The text states "In 2022 because the US had a lot of competition in the pharma industry, it started making excuses and turned the world’s head to a digressed topic of big oil."
#
# 7.  **Post-COVID: US and Russian Companies Profit from Vaccines:** This follows the COVID-19 pandemic.
#
#     *   **Reasoning:** The text states "After covid, US companies like Jonson and Jonson, and Pfizer started doing good with the vaccine market. So did some Russian companies."
#
# 8.  **Late 2019/Fall 2020: International Students Unable to Attend US Universities:** This is linked to Joe Biden's election.
#
#     *   **Reasoning:** The text states "In late 2019 the international students of law and politics who applied to the universities in the US for fall 2020 could not attend because Joe Biden was elected and foolishly undid all the good military impacts that the Trump administration had for world safety over the last 4 years."
#
# 9.  **2020: Joe Biden Elected, Undoing Trump's Policies:** This is the cause for the previous event.
#
#     *   **Reasoning:** The text states "In late 2019 the international students of law and politics who applied to the universities in the US for fall 2020 could not attend because Joe Biden was elected and foolishly undid all the good military impacts that the Trump administration had for world safety over the last 4 years."
#
# 10. **2020: US Sends Aircraft Carrier to Meddle in China's Politics:** This is presented as Biden's first action.
#
#     *   **Reasoning:** The text states "Biden’s 1st foolish move was to send an aircraft carrier to meddle in China’s personal politics since then China did not recognize Taiwan as an independent state."
#
# 11. **2020: COVID-19 Pandemic Affects Global Geo-Politics and Socio-Economics:** This is a major global event.
#
#     *   **Reasoning:** The text states "In 2020 the world was evolving into a sensitive situation with the Chinese demons spreading covid and affecting the global geo-politics and socio-economics."
#
# 12. **2020: Azerbaijan Attacks Nagorno-Karabakh:** This event is explicitly dated.
#
#     *   **Reasoning:** The text states "And then in 2020 when Azerbaijan attacked the beautiful country, the time when ISIS activity was low on the Georgia border, and China was testing its hypersonic vehicles secretly since 2018, the beautiful country suffered much damage on the Nagorno-Karabkh region."
#
# 13. **2018: China Secretly Testing Hypersonic Vehicles:** This is mentioned in relation to the 2020 Azerbaijan attack.
#
#     *   **Reasoning:** The text states "And then in 2020 when Azerbaijan attacked the beautiful country, the time when ISIS activity was low on the Georgia border, and China was testing its hypersonic vehicles secretly since 2018, the beautiful country suffered much damage on the Nagorno-Karabkh region."
#
# 14. **2007: Russia Plants Flag on North Pole Seabed:** This is an explicitly dated event.
#
#     *   **Reasoning:** The text states "Russia planted its flag on the seabed of the North Pole in August 2007, during the "Arktika 2007" expedition."
#
# 15. **1992: Russia Starts Patrolling Armenian Border:** This is the earliest dated event.
#
#     *   **Reasoning:** The text states "Well technically the patrolling started in 1992 according to some treaty to safeguard Armenia against Azerbaijan and Israel, and Turkey."
#
# 16. **1915: Armenian Genocide:** This is the earliest event mentioned.
#
#     *   **Reasoning:** The text states "Armenia also suffered a genocide in 1915."

# %%
# Question 1
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "/content/question3.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)

    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")

##### Answer Check failure-cluster
#All answers were sufficiently correct in terms of logic
# Instead of creating absolute time periods, it is clustering activities based on similiarty. Example- Covid and pharma ; US election of 2020 and war effects.
# Although technically these events should be categoried together under 2020
# AI is considering Bias, Causality and Corellation in its reasoning, and categorizing even when not told to.
# Out:
# Question:
# --------------------------------------------------------------------------------
# Russia planted its flag on the seabed of the North Pole in August 2007, during the "Arktika 2007" expedition. Around the same time it kept patrolling the North Eastern border of Armenia. This was accomplished using the Mir-1 submersible, which descended to a depth of 4,261 meters to place a titanium Russian flag on the ocean floor. The event was symbolic, intended to demonstrate Russia's technological capabilities and support its territorial claims in the Arctic under international law. Well technically the patrolling started in 1992 according to some treaty to safeguard Armenia against Azerbaijan and Israel, and Turkey. Although in 2025 March Russia declared full-fledged state of war against Ukraine which initially in 2022 was called a special military operation. Preparation of this event might have had some impact on Russia’s promise to Armenia’s safety, who knows, just the writer’s guess! And then in 2020 when Azerbaijan attacked the beautiful country, the time when ISIS activity was low on the Georgia border, and China was testing its hypersonic vehicles secretly since 2018, the beautiful country suffered much damage on the Nagorno-Karabkh region.
# In 2020 the world was evolving into a sensitive situation with the Chinese demons spreading covid and affecting the global geo-politics and socio-economics. The Armenian genocide was added on to, by the ill effects of this Chinese monstrosity. Armenia also suffered a genocide in 1915. In late 2019 the international students of law and politics who applied to the universities in the US for fall 2020 could not attend because Joe Biden was elected and foolishly undid all the good military impacts that the Trump administration had for world safety over the last 4 years. Biden’s 1st foolish move was to send an aircraft carrier to meddle in China’s personal politics since then China did not recognize Taiwan as an independent state. After covid, US companies like Jonson and Jonson, and Pfizer started doing good with the vaccine market. So did some Russian companies. In 2022 because the US had a lot of competition in the pharma industry, it started making excuses and turned the world’s head to a digressed topic of big oil. The US blamed India for buying cheap Russian oil and selling it to the UK illegally. Well, that country was officially termed Irony and Hypocrisy in 2023. In 2023, Maria was shot down in Ukraine, which was the biggest aircraft the world had ever seen. In 2025, the US declared trade tariffs on Canada, China, Mexico, and India, also calling Canada its 51st state.
# Given the above storyline alone, list all the events that were happening in the same time time, that is overlapping. Also list the stakeholders in those events, and give your reasoning for your generated lists.
# --------------------------------------------------------------------------------
#
# Gemini's Response:
# --------------------------------------------------------------------------------
# Okay, let's break down the overlapping events and stakeholders based solely on the provided storyline.
#
# **Overlapping Events and Stakeholders (Based on Storyline):**
#
# Here's a breakdown, focusing on events happening concurrently or in close proximity, and the involved parties:
#
# **1.  Around 2007:**
#
# *   **Event 1:** Russia plants flag at North Pole seabed.
#     *   **Stakeholders:** Russia
#     *   **Reasoning:** The storyline explicitly states this event.
# *   **Event 2:** Russia patrols Armenia's northeastern border.
#     *   **Stakeholders:** Russia, Armenia, Azerbaijan, Turkey (implied threat)
#     *   **Reasoning:** The storyline mentions this patrolling activity, citing a treaty to safeguard Armenia.
#
# **2.  2018 - 2020:**
#
# *   **Event 1:** China secretly tests hypersonic vehicles.
#     *   **Stakeholders:** China
#     *   **Reasoning:** Directly stated in the storyline.
# *   **Event 2:** Azerbaijan attacks Nagorno-Karabakh region.
#     *   **Stakeholders:** Azerbaijan, Armenia, Nagorno-Karabakh region
#     *   **Reasoning:** Explicitly mentioned in the storyline.
# *   **Event 3:** ISIS activity is low on the Georgia border.
#     *   **Stakeholders:** Georgia, ISIS (implied), potentially Russia (given its regional interests)
#     *   **Reasoning:** The storyline mentions this in the context of the Azerbaijan attack, suggesting a possible link or shift in regional dynamics.
#
# **3.  Late 2019 - 2020:**
#
# *   **Event 1:** International students unable to attend US universities due to Joe Biden's election.
#     *   **Stakeholders:** International students, US universities, US government (Biden administration)
#     *   **Reasoning:** The storyline directly links these events.
# *   **Event 2:** Joe Biden undoes Trump administration's military impacts.
#     *   **Stakeholders:** US government (Biden and Trump administrations), potentially global actors affected by US military policy.
#     *   **Reasoning:** The storyline presents this as a direct consequence of Biden's election.
#
# **4.  2020 - Ongoing:**
#
# *   **Event 1:** COVID-19 pandemic and its global impact.
#     *   **Stakeholders:** Global population, governments worldwide, healthcare systems, economies worldwide, China (as the alleged origin)
#     *   **Reasoning:** The storyline mentions COVID-19's impact on geopolitics and socioeconomics.
# *   **Event 2:** Pharmaceutical companies (US and Russian) benefit from vaccine market.
#     *   **Stakeholders:** Johnson & Johnson, Pfizer, Russian pharmaceutical companies, global population (as vaccine recipients)
#     *   **Reasoning:** The storyline mentions this in the context of the pandemic.
#
# **5.  2022:**
#
# *   **Event 1:** US blames India for buying cheap Russian oil and selling it to the UK.
#     *   **Stakeholders:** US, India, UK, Russia
#     *   **Reasoning:** Directly stated in the storyline.
# *   **Event 2:** US focuses on big oil as a digressed topic.
#     *   **Stakeholders:** US, big oil companies, global energy market
#     *   **Reasoning:** The storyline presents this as a diversionary tactic.
#
# **6.  2022 - 2025:**
#
# *   **Event 1:** Russia's war against Ukraine.
#     *   **Stakeholders:** Russia, Ukraine, NATO (implied), potentially other countries providing aid or sanctions.
#     *   **Reasoning:** The storyline mentions the escalation of the conflict.
#
# **7.  2023:**
#
# *   **Event 1:** Maria aircraft shot down in Ukraine.
#     *   **Stakeholders:** Ukraine, Russia
#     *   **Reasoning:** Directly stated in the storyline.
#
# **8.  2025:**
#
# *   **Event 1:** US declares trade tariffs on Canada, China, Mexico, and India, also calling Canada its 51st state.
#     *   **Stakeholders:** US, Canada, China, Mexico, India
#     *   **Reasoning:** Directly stated in the storyline.
#
# **Important Considerations:**
#
# *   **Bias:** The storyline is clearly biased, presenting events with a particular perspective and making unsubstantiated claims (e.g., "Chinese demons spreading COVID").
# *   **Causality vs. Correlation:** The storyline often implies causal relationships between events that may only be correlated.  It's important to remember that correlation does not equal causation.
# *   **Limited Information:** The analysis is based solely on the information provided in the storyline. A more comprehensive understanding would require additional context and reliable sources.

# %%
# Question 1
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "/content/question4.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)

    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")

##### Answer Check - partial failure
#All such events not answered, events listed which have something ot do with the country in question. Attention is not given to other events in the same timeline as event A.
# Out:
# Question:
# --------------------------------------------------------------------------------
# Russia planted its flag on the seabed of the North Pole in August 2007, during the "Arktika 2007" expedition. Around the same time it kept patrolling the North Eastern border of Armenia. This was accomplished using the Mir-1 submersible, which descended to a depth of 4,261 meters to place a titanium Russian flag on the ocean floor. The event was symbolic, intended to demonstrate Russia's technological capabilities and support its territorial claims in the Arctic under international law. Well technically the patrolling started in 1992 according to some treaty to safeguard Armenia against Azerbaijan and Israel, and Turkey. Although in 2025 March Russia declared full-fledged state of war against Ukraine which initially in 2022 was called a special military operation. Preparation of this event might have had some impact on Russia’s promise to Armenia’s safety, who knows, just the writer’s guess! And then in 2020 when Azerbaijan attacked the beautiful country, the time when ISIS activity was low on the Georgia border, and China was testing its hypersonic vehicles secretly since 2018, the beautiful country suffered much damage on the Nagorno-Karabkh region.
# (A) In 2020 the world was evolving into a sensitive situation with the Chinese demons spreading covid and affecting the global geo-politics and socio-economics. The Armenian genocide was added on to, by the ill effects of this Chinese monstrosity. Armenia also suffered a genocide in 1915. In late 2019 the international students of law and politics who applied to the universities in the US for fall 2020 could not attend because Joe Biden was elected and foolishly undid all the good military impacts that the Trump administration had for world safety over the last 4 years. Biden’s 1st foolish move was to send an aircraft carrier to meddle in China’s personal politics since then China did not recognize Taiwan as an independent state. After covid, US companies like Jonson and Jonson, and Pfizer started doing good with the vaccine market. So did some Russian companies. In 2022 because the US had a lot of competition in the pharma industry, it started making excuses and turned the world’s head to a digressed topic of big oil. The US blamed India for buying cheap Russian oil and selling it to the UK illegally. Well, that country was officially termed Irony and Hypocrisy in 2023. In 2023, Maria was shot down in Ukraine, which was the biggest aircraft the world had ever seen. In 2025, the US declared trade tariffs on Canada, China, Mexico, and India, also calling Canada its 51st state.
#
# Given the above storyline alone, which event was happing in parallel to event A, also give reasoning why. List all parallel events to event A.
# --------------------------------------------------------------------------------
#
# Gemini's Response:
# --------------------------------------------------------------------------------
# Here's an analysis of the events happening in parallel to event A, based solely on the provided text:
#
# **Event A:** "In 2020 the world was evolving into a sensitive situation with the Chinese demons spreading covid and affecting the global geo-politics and socio-economics. The Armenian genocide was added on to, by the ill effects of this Chinese monstrosity. Armenia also suffered a genocide in 1915."
#
# **Parallel Events:**
#
# *   **Azerbaijan attacked the Nagorno-Karabakh region:** The text states, "And then in 2020 when Azerbaijan attacked the beautiful country, the time when ISIS activity was low on the Georgia border, and China was testing its hypersonic vehicles secretly since 2018, the beautiful country suffered much damage on the Nagorno-Karabkh region." This clearly indicates that the attack occurred in 2020, coinciding with the events described in event A.
#
# **Reasoning:**
#
# The text explicitly places the Azerbaijan attack within the year 2020, the same year that event A describes the onset of the COVID-19 pandemic and its impact. Therefore, these events were happening concurrently.
#
# **Other events mentioned in the text that were happening in parallel to event A:**
#
# *   ISIS activity was low on the Georgia border
# *   China was testing its hypersonic vehicles secretly since 2018

# %%
# Question 1
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "/content/question5.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)

    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")

##### Answer Check
#Answer is mathematically correct. But the model is reading semantics wrong, the event B is specified to be in 2025, model is answering for 2023.
# Out:
# Question:
# --------------------------------------------------------------------------------
# Russia planted its flag on the seabed of the North Pole in August 2007, during the "Arktika 2007" expedition. Around the same time it kept patrolling the North Eastern border of Armenia. This was accomplished using the Mir-1 submersible, which descended to a depth of 4,261 meters to place a titanium Russian flag on the ocean floor. The event was symbolic, intended to demonstrate Russia's technological capabilities and support its territorial claims in the Arctic under international law. Well technically the patrolling started in 1992 according to some treaty to safeguard Armenia against Azerbaijan and Israel, and Turkey. Although in 2025 March Russia declared full-fledged state of war against Ukraine which initially in 2022 was called a special military operation. Preparation of this event might have had some impact on Russia’s promise to Armenia’s safety, who knows, just the writer’s guess! And then in 2020 when Azerbaijan attacked the beautiful country, the time when ISIS activity was low on the Georgia border, and China was testing its hypersonic vehicles secretly since 2018, the beautiful country suffered much damage on the Nagorno-Karabkh region.
# (A) In 2020 the world was evolving into a sensitive situation with the Chinese demons spreading covid and affecting the global geo-politics and socio-economics. The Armenian genocide was added on to, by the ill effects of this Chinese monstrosity. Armenia also suffered a genocide in 1915. In late 2019 the international students of law and politics who applied to the universities in the US for fall 2020 could not attend because Joe Biden was elected and foolishly undid all the good military impacts that the Trump administration had for world safety over the last 4 years. Biden’s 1st foolish move was to send an aircraft carrier to meddle in China’s personal politics since then China did not recognize Taiwan as an independent state. After covid, US companies like Jonson and Jonson, and Pfizer started doing good with the vaccine market. So did some Russian companies. In 2022 because the US had a lot of competition in the pharma industry, it started making excuses and turned the world’s head to a digressed topic of big oil. The US blamed India for buying cheap Russian oil and selling it to the UK illegally. Well, that country was officially termed Irony and Hypocrisy in 2023. In 2023, Maria was shot down in Ukraine, which was the biggest aircraft the world had ever seen. (B) In 2025, the US declared trade tariffs on Canada, China, Mexico, and India, also calling Canada its 51st state.
# Given the above storyline alone, list the number of events happening between A and B, also give reasoning why.
# --------------------------------------------------------------------------------
#
# Gemini's Response:
# --------------------------------------------------------------------------------
# Okay, let's analyze the provided text and identify the events occurring between sections (A) and (B).
#
# Here's a breakdown of the events mentioned in section (A):
#
# 1.  **2020:**
#     *   The world is evolving into a sensitive situation with the Chinese demons spreading covid and affecting the global geo-politics and socio-economics.
#     *   Armenia also suffered a genocide in 1915.
#     *   International students of law and politics who applied to the universities in the US for fall 2020 could not attend because Joe Biden was elected and foolishly undid all the good military impacts that the Trump administration had for world safety over the last 4 years.
#     *   Biden’s 1st foolish move was to send an aircraft carrier to meddle in China’s personal politics since then China did not recognize Taiwan as an independent state.
# 2.  **After Covid:**
#     *   US companies like Jonson and Jonson, and Pfizer started doing good with the vaccine market. So did some Russian companies.
# 3.  **2022:**
#     *   The US had a lot of competition in the pharma industry, it started making excuses and turned the world’s head to a digressed topic of big oil.
#     *   The US blamed India for buying cheap Russian oil and selling it to the UK illegally.
# 4.  **2023:**
#     *   That country was officially termed Irony and Hypocrisy.
#     *   Maria was shot down in Ukraine, which was the biggest aircraft the world had ever seen.
#
# Therefore, there are **9** events happening between A and B.

# %%
# Question 1
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "/content/question6.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)

    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")

##### Answer Check
#All answers were sufficiently correct
# Out:
# Question:
# --------------------------------------------------------------------------------
# Russia planted its flag on the seabed of the North Pole in August 2007, during the "Arktika 2007" expedition. Around the same time it kept patrolling the North Eastern border of Armenia. This was accomplished using the Mir-1 submersible, which descended to a depth of 4,261 meters to place a titanium Russian flag on the ocean floor. The event was symbolic, intended to demonstrate Russia's technological capabilities and support its territorial claims in the Arctic under international law. Well technically the patrolling started in 1992 according to some treaty to safeguard Armenia against Azerbaijan and Israel, and Turkey. Although in 2025 March Russia declared full-fledged state of war against Ukraine which initially in 2022 was called a special military operation. Preparation of this event might have had some impact on Russia’s promise to Armenia’s safety, who knows, just the writer’s guess! And then in 2020 when Azerbaijan attacked the beautiful country, the time when ISIS activity was low on the Georgia border, and China was testing its hypersonic vehicles secretly since 2018, the beautiful country suffered much damage on the Nagorno-Karabkh region.
# In 2020 the world was evolving into a sensitive situation with the Chinese demons spreading covid and affecting the global geo-politics and socio-economics. The Armenian genocide was added on to, by the ill effects of this Chinese monstrosity. Armenia also suffered a genocide in 1915. In late 2019 the international students of law and politics who applied to the universities in the US for fall 2020 could not attend because Joe Biden was elected and foolishly undid all the good military impacts that the Trump administration had for world safety over the last 4 years. Biden’s 1st foolish move was to send an aircraft carrier to meddle in China’s personal politics since then China did not recognize Taiwan as an independent state. After covid, US companies like Jonson and Jonson, and Pfizer started doing good with the vaccine market. So did some Russian companies. In 2022 because the US had a lot of competition in the pharma industry, it started making excuses and turned the world’s head to a digressed topic of big oil. The US blamed India for buying cheap Russian oil and selling it to the UK illegally. Well, that country was officially termed Irony and Hypocrisy in 2023. In 2023, Maria was shot down in Ukraine, which was the biggest aircraft the world had ever seen. In 2025, the US declared trade tariffs on Canada, China, Mexico, and India, also calling Canada its 51st state.
#
# Given the above storyline alone, which events were happening closest to Joe Biden's election, also give reasoning why. List all such events with dates.
# --------------------------------------------------------------------------------
#
# Gemini's Response:
# --------------------------------------------------------------------------------
# Based solely on the provided storyline, here are the events happening closest to Joe Biden's election in late 2019/early 2020, along with reasoning:
#
# *   **Late 2019:** International students of law and politics who applied to universities in the US for fall 2020 could not attend because Joe Biden was elected.
#     *   **Reasoning:** This event is directly tied to Biden's election, as it describes the immediate impact on students planning to attend US universities after his victory.
#
# *   **2020:** Azerbaijan attacked the Nagorno-Karabakh region of Armenia.
#     *   **Reasoning:** This event is placed in the same year as Biden's election, suggesting it occurred relatively close in time.
#
# *   **2020:** The world was evolving into a sensitive situation with the Chinese demons spreading covid and affecting the global geo-politics and socio-economics.
#     *   **Reasoning:** This event is placed in the same year as Biden's election, suggesting it occurred relatively close in time.
#
# It's important to note that the storyline presents a biased and potentially inaccurate account of events.

# %%
# Question 1
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "/content/question7.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)

    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")

##### Answer Check - Partial Failure
#Nagorno-Karabakh is told as a separate country - inconsistency in answers.
# In some previous answer it was called a part of another country.
# Out:
# Question:
# --------------------------------------------------------------------------------
# Russia planted its flag on the seabed of the North Pole in August 2007, during the "Arktika 2007" expedition. Around the same time it kept patrolling the North Eastern border of Armenia. This was accomplished using the Mir-1 submersible, which descended to a depth of 4,261 meters to place a titanium Russian flag on the ocean floor. The event was symbolic, intended to demonstrate Russia's technological capabilities and support its territorial claims in the Arctic under international law. Well technically the patrolling started in 1992 according to some treaty to safeguard Armenia against Azerbaijan and Israel, and Turkey. Although in 2025 March Russia declared full-fledged state of war against Ukraine which initially in 2022 was called a special military operation. Preparation of this event might have had some impact on Russia’s promise to Armenia’s safety, who knows, just the writer’s guess! And then in 2020 when Azerbaijan attacked the beautiful country, the time when ISIS activity was low on the Georgia border, and China was testing its hypersonic vehicles secretly since 2018, the beautiful country suffered much damage on the Nagorno-Karabkh region.
# In 2020 the world was evolving into a sensitive situation with the Chinese demons spreading covid and affecting the global geo-politics and socio-economics. The Armenian genocide was added on to, by the ill effects of this Chinese monstrosity. Armenia also suffered a genocide in 1915. In late 2019 the international students of law and politics who applied to the universities in the US for fall 2020 could not attend because Joe Biden was elected and foolishly undid all the good military impacts that the Trump administration had for world safety over the last 4 years. Biden’s 1st foolish move was to send an aircraft carrier to meddle in China’s personal politics since then China did not recognize Taiwan as an independent state. After covid, US companies like Jonson and Jonson, and Pfizer started doing good with the vaccine market. So did some Russian companies. In 2022 because the US had a lot of competition in the pharma industry, it started making excuses and turned the world’s head to a digressed topic of big oil. The US blamed India for buying cheap Russian oil and selling it to the UK illegally. Well, that country was officially termed Irony and Hypocrisy in 2023. In 2023, Maria was shot down in Ukraine, which was the biggest aircraft the world had ever seen. In 2025, the US declared trade tariffs on Canada, China, Mexico, and India, also calling Canada its 51st state.
#
# Given the above storyline alone, which country is called Irony and Hypocrisy, do you consider Nagorno-Karabakh a separate country, and which country in called the beautiful country, also give reasoning why. Gives dates of events mentioned across these instances.
# --------------------------------------------------------------------------------
#
# Gemini's Response:
# --------------------------------------------------------------------------------
# Okay, let's break down the information provided in the storyline:
#
# *   **Country called Irony and Hypocrisy:** According to the text, the **US** was officially termed "Irony and Hypocrisy" in 2023.
#
# *   **Nagorno-Karabakh as a separate country:** The text does not explicitly state whether Nagorno-Karabakh is a separate country. It refers to Armenia suffering damage in the Nagorno-Karabakh region during an attack by Azerbaijan. This implies that the writer does not consider Nagorno-Karabakh a separate country.
#
# *   **The beautiful country:** The text refers to **Armenia** as "the beautiful country." This is stated directly in the context of the 2020 attack by Azerbaijan.
#
# **Reasoning:**
#
# *   The text explicitly states the US was termed "Irony and Hypocrisy."
# *   The text describes Azerbaijan attacking Armenia *in* the Nagorno-Karabakh region, suggesting it's considered part of Armenia.
# *   The text directly calls Armenia "the beautiful country."
#
# **Dates of Events Mentioned:**
#
# *   **1915:** Armenian genocide
# *   **1992:** Russia starts patrolling the North Eastern border of Armenia.
# *   **2007:** Russia plants flag on North Pole seabed (Arktika 2007 expedition).
# *   **2018:** China starts secretly testing hypersonic vehicles.
# *   **Late 2019:** International students apply to US universities for Fall 2020.
# *   **2020:**
#     *   Azerbaijan attacks Armenia in Nagorno-Karabakh region.
#     *   COVID-19 pandemic begins.
#     *   Joe Biden elected in the US.
# *   **2022:**
#     *   Russia's "special military operation" in Ukraine begins.
#     *   US blames India for buying cheap Russian oil.
# *   **2023:**
#     *   US officially termed "Irony and Hypocrisy."
#     *   Maria aircraft shot down in Ukraine.
# *   **2025:**
#     *   Russia declares full-fledged state of war against Ukraine.
#     *   US declares trade tariffs on Canada, China, Mexico, and India, also calling Canada its 51st state.

# %%
# Question 1
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "/content/question8.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)

    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")

##### Answer Check
#All answers were sufficiently correct
# Out:
# Question:
# --------------------------------------------------------------------------------
# Russia planted its flag on the seabed of the North Pole in August 2007, during the "Arktika 2007" expedition. Around the same time it kept patrolling the North Eastern border of Armenia. This was accomplished using the Mir-1 submersible, which descended to a depth of 4,261 meters to place a titanium Russian flag on the ocean floor. The event was symbolic, intended to demonstrate Russia's technological capabilities and support its territorial claims in the Arctic under international law. Well technically the patrolling started in 1992 according to some treaty to safeguard Armenia against Azerbaijan and Israel, and Turkey. Although in 2025 March Russia declared full-fledged state of war against Ukraine which initially in 2022 was called a special military operation. Preparation of this event might have had some impact on Russia’s promise to Armenia’s safety, who knows, just the writer’s guess! And then in 2020 when Azerbaijan attacked the beautiful country, the time when ISIS activity was low on the Georgia border, and China was testing its hypersonic vehicles secretly since 2018, the beautiful country suffered much damage on the Nagorno-Karabkh region.
# In 2020 the world was evolving into a sensitive situation with the Chinese demons spreading covid and affecting the global geo-politics and socio-economics. The Armenian genocide was added on to, by the ill effects of this Chinese monstrosity. Armenia also suffered a genocide in 1915. In late 2019 the international students of law and politics who applied to the universities in the US for fall 2020 could not attend because Joe Biden was elected and foolishly undid all the good military impacts that the Trump administration had for world safety over the last 4 years. Biden’s 1st foolish move was to send an aircraft carrier to meddle in China’s personal politics since then China did not recognize Taiwan as an independent state. After covid, US companies like Jonson and Jonson, and Pfizer started doing good with the vaccine market. So did some Russian companies. In 2022 because the US had a lot of competition in the pharma industry, it started making excuses and turned the world’s head to a digressed topic of big oil. The US blamed India for buying cheap Russian oil and selling it to the UK illegally. Well, that country was officially termed Irony and Hypocrisy in 2023. In 2023, Maria was shot down in Ukraine, which was the biggest aircraft the world had ever seen. In 2025, the US declared trade tariffs on Canada, China, Mexico, and India, also calling Canada its 51st state.
#
# Given the above storyline alone, which was the first event, also give reasoning why.
# --------------------------------------------------------------------------------
#
# Gemini's Response:
# --------------------------------------------------------------------------------
# Based solely on the provided text, the first event is:
#
# **1915: Armenian Genocide**
#
# **Reasoning:**
#
# The text presents a chronological sequence of events, and the Armenian Genocide of 1915 is the earliest date mentioned. All other events are described as happening in later years.

# %%
# Question 1
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "/content/question9.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)

    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")

##### Answer Check
#All answers were sufficiently correct
# Out:
# Question:
# --------------------------------------------------------------------------------
# Russia planted its flag on the seabed of the North Pole in August 2007, during the "Arktika 2007" expedition. Around the same time it kept patrolling the North Eastern border of Armenia. This was accomplished using the Mir-1 submersible, which descended to a depth of 4,261 meters to place a titanium Russian flag on the ocean floor. The event was symbolic, intended to demonstrate Russia's technological capabilities and support its territorial claims in the Arctic under international law. Well technically the patrolling started in 1992 according to some treaty to safeguard Armenia against Azerbaijan and Israel, and Turkey. Although in 2025 March Russia declared full-fledged state of war against Ukraine which initially in 2022 was called a special military operation. Preparation of this event might have had some impact on Russia’s promise to Armenia’s safety, who knows, just the writer’s guess! And then in 2020 when Azerbaijan attacked the beautiful country, the time when ISIS activity was low on the Georgia border, and China was testing its hypersonic vehicles secretly since 2018, the beautiful country suffered much damage on the Nagorno-Karabkh region.
# In 2020 the world was evolving into a sensitive situation with the Chinese demons spreading covid and affecting the global geo-politics and socio-economics. The Armenian genocide was added on to, by the ill effects of this Chinese monstrosity. Armenia also suffered a genocide in 1915. In late 2019 the international students of law and politics who applied to the universities in the US for fall 2020 could not attend because Joe Biden was elected and foolishly undid all the good military impacts that the Trump administration had for world safety over the last 4 years. Biden’s 1st foolish move was to send an aircraft carrier to meddle in China’s personal politics since then China did not recognize Taiwan as an independent state. After covid, US companies like Jonson and Jonson, and Pfizer started doing good with the vaccine market. So did some Russian companies. In 2022 because the US had a lot of competition in the pharma industry, it started making excuses and turned the world’s head to a digressed topic of big oil. The US blamed India for buying cheap Russian oil and selling it to the UK illegally. Well, that country was officially termed Irony and Hypocrisy in 2023. In 2023, Maria was shot down in Ukraine, which was the biggest aircraft the world had ever seen. In 2025, the US declared trade tariffs on Canada, China, Mexico, and India, also calling Canada its 51st state.
#
# Given the above storyline alone, which event was the last event, also give reasoning why.
# --------------------------------------------------------------------------------
#
# Gemini's Response:
# --------------------------------------------------------------------------------
# The last event in the storyline is the US declaring trade tariffs on Canada, China, Mexico, and India, and calling Canada its 51st state.
#
# The storyline progresses chronologically, and this event is explicitly stated to have occurred in 2025. The other events are mentioned in earlier years.

# %%
# Question 1
# Import required libraries
import google.generativeai as genai
import os
from pathlib import Path

# Configure the API key
# Replace with your API key
GOOGLE_API_KEY = "AIzaSyBVwAxj816Qr34iZpScKlgU2QRPIED9at8"
genai.configure(api_key=GOOGLE_API_KEY)

# Initialize the Gemini model
model = genai.GenerativeModel('gemini-2.0-flash')

def read_question(file_path):
    """Read the question from a text file."""
    try:
        with open(file_path, 'r') as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading file: {e}")
        return None

def get_gemini_response(question):
    """Get response from Gemini model."""
    try:
        response = model.generate_content(
            question,
            generation_config={
                'temperature': 0.0,
            }
        )
        return response.text
    except Exception as e:
        print(f"Error getting response from Gemini: {e}")
        return None

# Process Question 1
question_file = "/content/question10.txt"
question_text = read_question(question_file)

if question_text:
    print("Question:")
    print("-" * 80)
    print(question_text)

    print("-" * 80)
    print("\nGemini's Response:")
    print("-" * 80)
    response = get_gemini_response(question_text)
    if response:
        print(response)
    else:
        print("Failed to get response from Gemini")

else:
    print("Failed to read question from file")

##### Answer Check
#All answers were very very well crafted and logically reasoned.
# Out:
# Question:
# --------------------------------------------------------------------------------
# Russia planted its flag on the seabed of the North Pole in August 2007, during the "Arktika 2007" expedition. Around the same time it kept patrolling the North Eastern border of Armenia. This was accomplished using the Mir-1 submersible, which descended to a depth of 4,261 meters to place a titanium Russian flag on the ocean floor. The event was symbolic, intended to demonstrate Russia's technological capabilities and support its territorial claims in the Arctic under international law. Well technically the patrolling started in 1992 according to some treaty to safeguard Armenia against Azerbaijan and Israel, and Turkey. Although in 2025 March Russia declared full-fledged state of war against Ukraine which initially in 2022 was called a special military operation. Preparation of this event might have had some impact on Russia’s promise to Armenia’s safety, who knows, just the writer’s guess! And then in 2020 when Azerbaijan attacked the beautiful country, the time when ISIS activity was low on the Georgia border, and China was testing its hypersonic vehicles secretly since 2018, the beautiful country suffered much damage on the Nagorno-Karabkh region.
# In 2020 the world was evolving into a sensitive situation with the Chinese demons spreading covid and affecting the global geo-politics and socio-economics. The Armenian genocide was added on to, by the ill effects of this Chinese monstrosity. Armenia also suffered a genocide in 1915. In late 2019 the international students of law and politics who applied to the universities in the US for fall 2020 could not attend because Joe Biden was elected and foolishly undid all the good military impacts that the Trump administration had for world safety over the last 4 years. Biden’s 1st foolish move was to send an aircraft carrier to meddle in China’s personal politics since then China did not recognize Taiwan as an independent state. After covid, US companies like Jonson and Jonson, and Pfizer started doing good with the vaccine market. So did some Russian companies. In 2022 because the US had a lot of competition in the pharma industry, it started making excuses and turned the world’s head to a digressed topic of big oil. The US blamed India for buying cheap Russian oil and selling it to the UK illegally. Well, that country was officially termed Irony and Hypocrisy in 2023. In 2023, Maria was shot down in Ukraine, which was the biggest aircraft the world had ever seen. In 2025, the US declared trade tariffs on Canada, China, Mexico, and India, also calling Canada its 51st state.
#
# Given the above storyline alone, what are the latest trade trends and how do you think they will affect the world in the time to come, also give reasoning why.
# --------------------------------------------------------------------------------
#
# Gemini's Response:
# --------------------------------------------------------------------------------
# Based solely on the provided storyline, here's an analysis of the latest trade trends and their potential impact:
#
# **Latest Trade Trends (According to the Storyline):**
#
# *   **US Imposing Trade Tariffs:** The US has declared trade tariffs on Canada, China, Mexico, and India.
# *   **US Accusations of Illegal Oil Trade:** The US accused India of buying cheap Russian oil and selling it to the UK illegally.
# *   **Competition in the Pharma Industry:** The US faces competition in the pharmaceutical industry, potentially from Russia and other countries.
#
# **Potential Impact on the World:**
#
# 1.  **Increased Trade Tensions and Protectionism:** The US imposing tariffs on major trading partners (Canada, China, Mexico, India) signals a move towards protectionism. This could lead to retaliatory tariffs from these countries, escalating into trade wars.
#     *   **Reasoning:** Tariffs increase the cost of imported goods, making domestic products more competitive. However, they also raise costs for consumers and businesses that rely on imported inputs. Retaliatory tariffs can disrupt global supply chains and harm economic growth.
#
# 2.  **Shift in Trade Alliances:** The US actions could push countries like China, India, and Mexico to strengthen trade ties with each other and other nations, forming alternative trade blocs.
#     *   **Reasoning:** Countries facing US tariffs may seek to diversify their trade relationships to reduce dependence on the US market. This could lead to the formation of new trade agreements and alliances that exclude the US.
#
# 3.  **Disruption of Global Supply Chains:** Trade wars and tariffs can disrupt global supply chains, as businesses struggle to find alternative sources of goods and materials.
#     *   **Reasoning:** Many industries rely on complex global supply chains, with different stages of production taking place in different countries. Tariffs can make these supply chains more expensive and less efficient, leading to higher prices and reduced availability of goods.
#
# 4.  **Economic Slowdown:** Trade tensions and protectionism can negatively impact global economic growth by reducing trade volumes, increasing uncertainty, and discouraging investment.
#     *   **Reasoning:** Trade is a major engine of economic growth, and disruptions to trade can have a significant impact on overall economic activity. Uncertainty about trade policies can also discourage businesses from investing and expanding.
#
# 5.  **Geopolitical Realignment:** Trade disputes can spill over into other areas of international relations, potentially leading to geopolitical tensions and conflicts.
#     *   **Reasoning:** Trade is often intertwined with political and security considerations. Trade disputes can exacerbate existing tensions between countries and lead to a breakdown in diplomatic relations.
#
# 6.  **Impact on the Pharma Industry:** Increased competition in the pharmaceutical industry could lead to lower prices for consumers, but also potentially reduced investment in research and development.
#     *   **Reasoning:** Competition can drive down prices and improve access to medicines. However, it can also reduce the profitability of pharmaceutical companies, potentially leading to less investment in developing new drugs.
#
# **Overall:**
#
# The storyline suggests a world moving towards greater trade protectionism, increased geopolitical tensions, and a potential realignment of global trade alliances. These trends could have significant negative consequences for global economic growth and stability.
